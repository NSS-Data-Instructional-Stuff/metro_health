# %%
import requests
import pandas as pd
import io

# %% [markdown]
# # APIs
#
# An Application Programming Interface, or API, is a structured way to retrieve data from a website. Using an API is safer and easier than something like webscraping, since what you get back is already in a usable format. Many organizations use APIs like:
# - Government organizations ([US Government](https://www.data.gov/developers/apis))
# - United States Census ([Census API](https://www.census.gov/data/developers/data-sets.html))
# - Large companies ([Twitter API](https://developer.twitter.com/en/docs))
# - News organizations ([NYT API](https://developer.nytimes.com/))
# - And [many more](https://github.com/public-apis/public-apis)
#
# If you type `how to use an api in python` in google, you get back many articles walking through how to use an API. It is a well documented and useful tool to be familiar with.

# %% [markdown]
# The CDC has a large number of datasets avaiable at https://data.cdc.gov/, which can be accessed using their API.
#
# Let's look at the COVID-19 Case Surveillance Public Use Data with Geography, located at https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data-with-Ge/n8mc-b4w4.
#
# The COVID-19 case surveillance database includes patient-level data reported by U.S. states and autonomous reporting entities, including New York City and the District of Columbia (D.C.), as well as U.S. territories and affiliates.
#
# If you browse to this page, you should see a button in the upper right labeled "API". Click this button and then change the value in the bottom right from JSON to CSV. Copy the API Endpoint.

# %%
URL = 'https://data.cdc.gov/resource/n8mc-b4w4.csv'

# %% [markdown]
# To interact with this we'll use the `requests` library.

# %%
response = requests.get(URL)

# %% [markdown]
# Once we have this response, we can check the status code. A 200 indicates success.

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# To take the result, we need to use the _io_ library to get it into a format that can be read into a _pandas_ DataFrame.

# %%
covid = pd.read_csv(io.StringIO(response.text))

# %%
covid
# Out:
#     case_month res_state  state_fips_code   res_county  county_fips_code  \
# 0      2020-12        AL                1    ST. CLAIR           26147.0
# 1      2020-05        AR                5       GREENE            5055.0
# 2      2020-11        OH               39        HENRY           39069.0
# 3      2020-11        KY               21   MUHLENBERG           21177.0
# 4      2020-05        NY               36        YATES           36123.0
# ..         ...       ...              ...          ...               ...
# 995    2021-01        IL               17       SALINE           17165.0
# 996    2021-01        IA               19       MARION           19125.0
# 997    2021-04        WI               55         SAUK           55111.0
# 998    2021-06        VA               51        WYTHE           51197.0
# 999    2020-10        IA               19  CERRO GORDO           19033.0
#
#           age_group   sex     race ethnicity  case_positive_specimen  \
# 0               NaN   NaN      NaN       NaN                     NaN
# 1      0 - 17 years   NaN      NaN       NaN                     0.0
# 2      0 - 17 years   NaN      NaN       NaN                     NaN
# 3    18 to 49 years   NaN      NaN       NaN                     NaN
# 4    50 to 64 years   NaN      NaN       NaN                     0.0
# ..              ...   ...      ...       ...                     ...
# 995    0 - 17 years  Male      NaN       NaN                     NaN
# 996  18 to 49 years  Male  Missing       NaN                     NaN
# 997  18 to 49 years  Male      NaN       NaN                     NaN
# 998  18 to 49 years  Male      NaN       NaN                     NaN
# 999  50 to 64 years  Male  Missing       NaN                     NaN
#
#      case_onset_interval              process exposure_yn  \
# 0                    NaN              Missing     Missing
# 1                    0.0              Missing     Missing
# 2                    0.0  Clinical evaluation     Unknown
# 3                    NaN              Missing     Missing
# 4                    NaN              Missing     Missing
# ..                   ...                  ...         ...
# 995                  0.0              Missing     Missing
# 996                  NaN              Missing     Missing
# 997                  0.0              Missing     Missing
# 998                  0.0              Missing     Missing
# 999                  NaN              Missing     Missing
#
#                 current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0                Probable Case        Missing  Missing  Missing  Missing
# 1    Laboratory-confirmed case    Symptomatic       No  Missing      NaN
# 2    Laboratory-confirmed case    Symptomatic       No  Missing      NaN
# 3    Laboratory-confirmed case        Missing       No  Missing       No
# 4                Probable Case        Missing  Missing  Missing      NaN
# ..                         ...            ...      ...      ...      ...
# 995  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 996              Probable Case        Missing  Missing  Missing  Missing
# 997  Laboratory-confirmed case    Symptomatic  Unknown  Missing      NaN
# 998  Laboratory-confirmed case    Symptomatic       No  Missing      NaN
# 999              Probable Case        Missing  Unknown  Missing  Missing
#
#     underlying_conditions_yn
# 0                        NaN
# 1                        Yes
# 2                        Yes
# 3                        NaN
# 4                        NaN
# ..                       ...
# 995                      NaN
# 996                      NaN
# 997                      NaN
# 998                      NaN
# 999                      NaN
#
# [1000 rows x 19 columns]

# %% [markdown]
# **Question:** What do you notice about the results?

# %% [markdown]
# This returned only 1000 results. It is common for APIs to limit the number of results returned.
#
# Click on the API Docs button and let's see if we can figure out how to get more results.
#
# If you click on the "Paging through Data" link, you'll find how to control this. It seems that by default, this API will only return 1000 results, but we can change this by using the `$limit` query parameter.
#
# One way to include a query parameter is to pass it as a dictionary to the `params` argument of `.get()`.

# %%
params = {
    '$limit': 5000
}

# %%
response = requests.get(URL, params = params)

covid = pd.read_csv(io.StringIO(response.text))
covid
# Out:
#      case_month res_state  state_fips_code  res_county  county_fips_code  \
# 0       2020-12        AL                1   ST. CLAIR           26147.0
# 1       2020-05        AR                5      GREENE            5055.0
# 2       2020-11        OH               39       HENRY           39069.0
# 3       2020-11        KY               21  MUHLENBERG           21177.0
# 4       2020-05        NY               36       YATES           36123.0
# ...         ...       ...              ...         ...               ...
# 4995    2020-11        KS               20      SUMNER           20191.0
# 4996    2020-10        WI               55     WAUPACA           55135.0
# 4997    2021-04        TN               47      MCMINN           47107.0
# 4998    2021-01        NE               31       DODGE           31053.0
# 4999    2020-10        CT                9   MIDDLESEX            9007.0
#
#            age_group     sex     race ethnicity  case_positive_specimen  \
# 0                NaN     NaN      NaN       NaN                     NaN
# 1       0 - 17 years     NaN      NaN       NaN                     0.0
# 2       0 - 17 years     NaN      NaN       NaN                     NaN
# 3     18 to 49 years     NaN      NaN       NaN                     NaN
# 4     50 to 64 years     NaN      NaN       NaN                     0.0
# ...              ...     ...      ...       ...                     ...
# 4995  50 to 64 years  Female      NaN       NaN                     NaN
# 4996  50 to 64 years  Female      NaN       NaN                     NaN
# 4997       65+ years  Female      NaN       NaN                     NaN
# 4998    0 - 17 years    Male      NaN       NaN                     NaN
# 4999    0 - 17 years    Male  Missing   Missing                     NaN
#
#       case_onset_interval              process exposure_yn  \
# 0                     NaN              Missing     Missing
# 1                     0.0              Missing     Missing
# 2                     0.0  Clinical evaluation     Unknown
# 3                     NaN              Missing     Missing
# 4                     NaN              Missing     Missing
# ...                   ...                  ...         ...
# 4995                  NaN              Missing     Missing
# 4996                  0.0              Missing     Missing
# 4997                  NaN              Missing     Missing
# 4998                  0.0              Missing     Missing
# 4999                  NaN              Missing     Missing
#
#                  current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0                 Probable Case        Missing  Missing  Missing  Missing
# 1     Laboratory-confirmed case    Symptomatic       No  Missing      NaN
# 2     Laboratory-confirmed case    Symptomatic       No  Missing      NaN
# 3     Laboratory-confirmed case        Missing       No  Missing       No
# 4                 Probable Case        Missing  Missing  Missing      NaN
# ...                         ...            ...      ...      ...      ...
# 4995  Laboratory-confirmed case        Unknown  Unknown  Unknown       No
# 4996  Laboratory-confirmed case    Symptomatic  Unknown  Missing  Unknown
# 4997  Laboratory-confirmed case        Missing  Missing  Missing      NaN
# 4998  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4999  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#      underlying_conditions_yn
# 0                         NaN
# 1                         Yes
# 2                         Yes
# 3                         NaN
# 4                         NaN
# ...                       ...
# 4995                      NaN
# 4996                      NaN
# 4997                      NaN
# 4998                      NaN
# 4999                      NaN
#
# [5000 rows x 19 columns]

# %% [markdown]
# What if we don't care about the whole country and only want to get the results for Tennessee?
#
# To accomplish this, we can filter by specifying the state parameter.

# %%
params = {
    '$limit': 5000,
    'res_state': 'TN'
}

# %%
response = requests.get(URL, params = params)

covid = pd.read_csv(io.StringIO(response.text))
covid
# Out:
#      case_month res_state  state_fips_code  res_county  county_fips_code  \
# 0       2020-07        TN               47  LAUDERDALE             47097
# 1       2020-12        TN               47     MCNAIRY             47109
# 2       2020-12        TN               47     FAYETTE             47047
# 3       2020-06        TN               47      SEVIER             47155
# 4       2020-12        TN               47   ROBERTSON             47147
# ...         ...       ...              ...         ...               ...
# 4995    2020-12        TN               47        RHEA             47143
# 4996    2020-12        TN               47       MAURY             47119
# 4997    2020-12        TN               47      WARREN             47177
# 4998    2020-12        TN               47      COFFEE             47031
# 4999    2020-12        TN               47     HAMBLEN             47063
#
#            age_group     sex            race        ethnicity  \
# 0     18 to 49 years  Female             NaN              NaN
# 1     18 to 49 years  Female         Unknown          Missing
# 2     50 to 64 years    Male         Missing          Missing
# 3       0 - 17 years  Female           White  Hispanic/Latino
# 4     18 to 49 years  Female           White  Hispanic/Latino
# ...              ...     ...             ...              ...
# 4995  50 to 64 years    Male             NaN              NaN
# 4996  18 to 49 years    Male  Multiple/Other          Missing
# 4997       65+ years    Male             NaN              NaN
# 4998  18 to 49 years  Female           White          Missing
# 4999    0 - 17 years    Male           White          Missing
#
#       case_positive_specimen  case_onset_interval  process exposure_yn  \
# 0                        NaN                  0.0  Missing     Missing
# 1                        NaN                  NaN  Missing     Missing
# 2                        NaN                  NaN  Missing     Missing
# 3                        NaN                  0.0  Missing     Missing
# 4                        NaN                  NaN  Missing     Missing
# ...                      ...                  ...      ...         ...
# 4995                     NaN                  NaN  Missing     Missing
# 4996                     NaN                  NaN  Missing     Missing
# 4997                     NaN                  NaN  Missing     Missing
# 4998                     NaN                  NaN  Missing     Missing
# 4999                     NaN                  NaN  Missing     Missing
#
#                  current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0     Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 1     Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 2     Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 3     Laboratory-confirmed case    Symptomatic       No       No       No
# 4     Laboratory-confirmed case    Symptomatic       No       No      NaN
# ...                         ...            ...      ...      ...      ...
# 4995  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 4996  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 4997  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 4998  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 4999  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#      underlying_conditions_yn
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         Yes
# ...                       ...
# 4995                      NaN
# 4996                      NaN
# 4997                      Yes
# 4998                      NaN
# 4999                      NaN
#
# [5000 rows x 19 columns]

# %% [markdown]
# **Your Turn:** Use the API to retrieve data to retrieve all cases that happened in Davidson County, TN in which the patient was hospitalized. In what percentage of those cases did the patient die?
