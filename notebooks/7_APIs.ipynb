# %%
import requests
import pandas as pd
import io

# %% [markdown]
# # APIs
#
# An Application Programming Interface, or API, is a structured way to retrieve data from a website. Using an API is safer and easier than something like webscraping, since what you get back is already in a usable format. Many organizations use APIs like:
# - Government organizations ([US Government](https://www.data.gov/developers/apis))
# - Large companies ([Twitter API](https://developer.twitter.com/en/docs))
# - News organizations ([NYT API](https://developer.nytimes.com/))
# - And [many more](https://github.com/public-apis/public-apis)
#
# If you type `how to use an api in python` in google, you get back many articles walking through how to use an API. It is a well documented and useful tool to be familiar with.

# %% [markdown]
# The CDC has a large number of datasets avaiable at https://data.cdc.gov/, which can be accessed using their API.
#
# Let's look at the Vaccine Hesitancy for COVID-19: County and local estimates dataset, located at https://data.cdc.gov/Vaccinations/Vaccine-Hesitancy-for-COVID-19-County-and-local-es/q9mh-h2tw.
#
# If you browse to this page, you should see a button in the upper right labeled "API". Click this button and then change the value in the bottom right from JSON to CSV. Copy the API Endpoint.

# %%
URL = 'https://data.cdc.gov/resource/q9mh-h2tw.csv'

# %% [markdown]
# To interact with this we'll use the `requests` library.

# %%
response = requests.get(URL)

# %% [markdown]
# Once we have this response, we can check the status code. A 200 indicates success.

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# To take the result, we need to use the _io_ library to get it into a format that can be read into a _pandas_ DataFrame.

# %%
vaccine_hesitancy = pd.read_csv(io.StringIO(response.text))

# %%
vaccine_hesitancy
# Out:
#      fips_code                 county_name    state  estimated_hesitant  \
# 0         1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 1         1121   Talladega County, Alabama  ALABAMA              0.1783
# 2         1131      Wilcox County, Alabama  ALABAMA              0.1735
# 3         1129  Washington County, Alabama  ALABAMA              0.1735
# 4         1133     Winston County, Alabama  ALABAMA              0.1805
# ..         ...                         ...      ...                 ...
# 995      20003     Anderson County, Kansas   KANSAS              0.1560
# 996      19029           Cass County, Iowa     IOWA              0.1323
# 997      19171           Tama County, Iowa     IOWA              0.1293
# 998      19085       Harrison County, Iowa     IOWA              0.1323
# 999      19173         Taylor County, Iowa     IOWA              0.1362
#
#      estimated_hesitant_or_unsure  estimated_strongly_hesitant  \
# 0                          0.2400                       0.1383
# 1                          0.2350                       0.1368
# 2                          0.2357                       0.1337
# 3                          0.2357                       0.1337
# 4                          0.2313                       0.1379
# ..                            ...                          ...
# 995                        0.2068                       0.0963
# 996                        0.1905                       0.0795
# 997                        0.1877                       0.0781
# 998                        0.1905                       0.0795
# 999                        0.1966                       0.0841
#
#      social_vulnerability_index             svi_category  \
# 0                          0.89  Very High Vulnerability
# 1                          0.87  Very High Vulnerability
# 2                          0.93  Very High Vulnerability
# 3                          0.73       High Vulnerability
# 4                          0.70       High Vulnerability
# ..                          ...                      ...
# 995                        0.23        Low Vulnerability
# 996                        0.20   Very Low Vulnerability
# 997                        0.33        Low Vulnerability
# 998                        0.06   Very Low Vulnerability
# 999                        0.28        Low Vulnerability
#
#      ability_to_handle_a_covid      cvac_category  ...  percent_hispanic  \
# 0                         0.64       High Concern  ...            0.0242
# 1                         0.84  Very High Concern  ...            0.0229
# 2                         0.94  Very High Concern  ...            0.0053
# 3                         0.82  Very High Concern  ...            0.0146
# 4                         0.80       High Concern  ...            0.0315
# ..                         ...                ...  ...               ...
# 995                       0.63       High Concern  ...            0.0189
# 996                       0.09   Very Low Concern  ...            0.0270
# 997                       0.10   Very Low Concern  ...            0.0978
# 998                       0.02   Very Low Concern  ...            0.0174
# 999                       0.14   Very Low Concern  ...            0.0770
#
#      percent_non_hispanic_american  percent_non_hispanic_asian  \
# 0                           0.0022                      0.0036
# 1                           0.0043                      0.0061
# 2                           0.0009                      0.0003
# 3                           0.0731                      0.0025
# 4                           0.0034                      0.0016
# ..                             ...                         ...
# 995                         0.0209                      0.0001
# 996                         0.0024                      0.0028
# 997                         0.0723                      0.0046
# 998                         0.0004                      0.0049
# 999                         0.0005                      0.0102
#
#      percent_non_hispanic_black  percent_non_hispanic_native  \
# 0                        0.2697                       0.0000
# 1                        0.3237                       0.0003
# 2                        0.6938                       0.0000
# 3                        0.2354                       0.0000
# 4                        0.0073                       0.0005
# ..                          ...                          ...
# 995                      0.0050                       0.0000
# 996                      0.0020                       0.0014
# 997                      0.0092                       0.0000
# 998                      0.0019                       0.0004
# 999                      0.0002                       0.0000
#
#      percent_non_hispanic_white            geographical_point state_code  \
# 0                        0.6887  POINT (-86.844516 32.756889)         AL
# 1                        0.6263  POINT (-86.844516 32.756889)         AL
# 2                        0.2684  POINT (-86.844516 32.756889)         AL
# 3                        0.6495  POINT (-86.844516 32.756889)         AL
# 4                        0.9370  POINT (-86.844516 32.756889)         AL
# ..                          ...                           ...        ...
# 995                      0.9484   POINT (-98.38018 38.484729)         KS
# 996                      0.9529  POINT (-93.500061 42.074659)         IA
# 997                      0.8075  POINT (-93.500061 42.074659)         IA
# 998                      0.9620  POINT (-93.500061 42.074659)         IA
# 999                      0.9038  POINT (-93.500061 42.074659)         IA
#
#                                        county_boundary  \
# 0    MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 1    MULTIPOLYGON (((-86.303069 33.46316, -86.30306...
# 2    MULTIPOLYGON (((-87.52534299999999 32.132773, ...
# 3    MULTIPOLYGON (((-88.45317899999999 31.505388, ...
# 4    MULTIPOLYGON (((-87.63656399999999 34.120908, ...
# ..                                                 ...
# 995  MULTIPOLYGON (((-95.36024599999999 38.39013699...
# 996  MULTIPOLYGON (((-95.155284 41.331877999999996,...
# 997  MULTIPOLYGON (((-92.76746299999999 42.21013999...
# 998  MULTIPOLYGON (((-96.07862899999999 41.761963, ...
# 999  MULTIPOLYGON (((-94.928664 40.813596, -94.9286...
#
#                                         state_boundary
# 0    MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 1    MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 2    MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 3    MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 4    MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# ..                                                 ...
# 995  MULTIPOLYGON (((-102.045212 38.697567, -102.04...
# 996  MULTIPOLYGON (((-96.49877599999999 42.561043, ...
# 997  MULTIPOLYGON (((-96.49877599999999 42.561043, ...
# 998  MULTIPOLYGON (((-96.49877599999999 42.561043, ...
# 999  MULTIPOLYGON (((-96.49877599999999 42.561043, ...
#
# [1000 rows x 21 columns]

# %% [markdown]
# **Question:** What do you notice about the results?

# %% [markdown]
# This returned only 1000 results. It is common for APIs to limit the number of results returned.
#
# Click on the API Docs button and let's see if we can figure out how to get more results.
#
# If you click on the "Paging through Data" link, you'll find how to control this. It seems that by default, this API will only return 1000 results, but we can change this by using the `$limit` query parameter.
#
# One way to include a query parameter is to pass it as a dictionary to the `params` argument of `.get()`.

# %%
params = {
    '$limit': 5000
}

# %%
response = requests.get(URL, params = params)

vaccine_hesitancy = pd.read_csv(io.StringIO(response.text))
vaccine_hesitancy

# %% [markdown]
# What if we don't care about the whole country and only want to get the results for Tennessee?
#
# To accomplish this, we can filter by specifying the state parameter.

# %%
params = {
    'state': 'TENNESSEE'
}

# %%
response = requests.get(URL, params = params)

vaccine_hesitancy = pd.read_csv(io.StringIO(response.text))
vaccine_hesitancy
# Out:
#     fips_code                   county_name      state  estimated_hesitant  \
# 0       47155      Sevier County, Tennessee  TENNESSEE              0.1411
# 1       47165      Sumner County, Tennessee  TENNESSEE              0.1221
# 2       47175   Van Buren County, Tennessee  TENNESSEE              0.1382
# 3       47167      Tipton County, Tennessee  TENNESSEE              0.1337
# 4       47189      Wilson County, Tennessee  TENNESSEE              0.1169
# ..        ...                           ...        ...                 ...
# 90      47105      Loudon County, Tennessee  TENNESSEE              0.1260
# 91      47147   Robertson County, Tennessee  TENNESSEE              0.1408
# 92      47169   Trousdale County, Tennessee  TENNESSEE              0.1519
# 93      47091     Johnson County, Tennessee  TENNESSEE              0.1400
# 94      47125  Montgomery County, Tennessee  TENNESSEE              0.1336
#
#     estimated_hesitant_or_unsure  estimated_strongly_hesitant  \
# 0                         0.2073                       0.0884
# 1                         0.1799                       0.0754
# 2                         0.2064                       0.0879
# 3                         0.2022                       0.0837
# 4                         0.1696                       0.0722
# ..                           ...                          ...
# 90                        0.1874                       0.0786
# 91                        0.2067                       0.0884
# 92                        0.2256                       0.0968
# 93                        0.2081                       0.0885
# 94                        0.2078                       0.0811
#
#     social_vulnerability_index            svi_category  \
# 0                         0.61      High Vulnerability
# 1                         0.21       Low Vulnerability
# 2                         0.60      High Vulnerability
# 3                         0.45  Moderate Vulnerability
# 4                         0.15  Very Low Vulnerability
# ..                         ...                     ...
# 90                        0.39       Low Vulnerability
# 91                        0.43  Moderate Vulnerability
# 92                        0.52  Moderate Vulnerability
# 93                        0.57  Moderate Vulnerability
# 94                        0.52  Moderate Vulnerability
#
#     ability_to_handle_a_covid      cvac_category  ...  percent_hispanic  \
# 0                        0.53   Moderate Concern  ...            0.0599
# 1                        0.63       High Concern  ...            0.0488
# 2                        0.97  Very High Concern  ...            0.0071
# 3                        0.66       High Concern  ...            0.0278
# 4                        0.56   Moderate Concern  ...            0.0423
# ..                        ...                ...  ...               ...
# 90                       0.46   Moderate Concern  ...            0.0878
# 91                       0.62       High Concern  ...            0.0693
# 92                       0.73       High Concern  ...            0.0108
# 93                       0.85  Very High Concern  ...            0.0203
# 94                       0.71       High Concern  ...            0.1001
#
#     percent_non_hispanic_american  percent_non_hispanic_asian  \
# 0                          0.0039                      0.0078
# 1                          0.0025                      0.0140
# 2                          0.0000                      0.0000
# 3                          0.0029                      0.0067
# 4                          0.0029                      0.0164
# ..                            ...                         ...
# 90                         0.0013                      0.0072
# 91                         0.0023                      0.0056
# 92                         0.0053                      0.0024
# 93                         0.0051                      0.0048
# 94                         0.0046                      0.0214
#
#     percent_non_hispanic_black  percent_non_hispanic_native  \
# 0                       0.0090                       0.0002
# 1                       0.0727                       0.0004
# 2                       0.0028                       0.0000
# 3                       0.1836                       0.0000
# 4                       0.0712                       0.0002
# ..                         ...                          ...
# 90                      0.0092                       0.0000
# 91                      0.0719                       0.0006
# 92                      0.1018                       0.0000
# 93                      0.0345                       0.0000
# 94                      0.1929                       0.0037
#
#     percent_non_hispanic_white            geographical_point state_code  \
# 0                       0.8999  POINT (-86.343226 35.842998)         TN
# 1                       0.8412  POINT (-86.343226 35.842998)         TN
# 2                       0.9571  POINT (-86.343226 35.842998)         TN
# 3                       0.7569  POINT (-86.343226 35.842998)         TN
# 4                       0.8497  POINT (-86.343226 35.842998)         TN
# ..                         ...                           ...        ...
# 90                      0.8769  POINT (-86.343226 35.842998)         TN
# 91                      0.8326  POINT (-86.343226 35.842998)         TN
# 92                      0.8416  POINT (-86.343226 35.842998)         TN
# 93                      0.9229  POINT (-86.343226 35.842998)         TN
# 94                      0.6333  POINT (-86.343226 35.842998)         TN
#
#                                       county_boundary  \
# 0   MULTIPOLYGON (((-83.784379 35.876163, -83.7841...
# 1   MULTIPOLYGON (((-86.690759 36.409742, -86.6909...
# 2   MULTIPOLYGON (((-85.597422 35.726036, -85.5982...
# 3   MULTIPOLYGON (((-89.86997199999999 35.582524, ...
# 4   MULTIPOLYGON (((-86.5809 36.208819, -86.580764...
# ..                                                ...
# 90  MULTIPOLYGON (((-84.388333 35.768682999999996,...
# 91  MULTIPOLYGON (((-87.073559 36.427653, -87.0811...
# 92  MULTIPOLYGON (((-86.268898 36.450441999999995,...
# 93  MULTIPOLYGON (((-81.951482 36.473863, -81.9539...
# 94  MULTIPOLYGON (((-87.475678 36.640395999999996,...
#
#                                        state_boundary
# 0   MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 1   MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 2   MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 3   MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 4   MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# ..                                                ...
# 90  MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 91  MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 92  MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 93  MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
# 94  MULTIPOLYGON (((-82.222064 36.15696, -82.22427...
#
# [95 rows x 21 columns]

# %% [markdown]
# **Your Turn:** Find another dataset available from the CDC that looks interesting to you and utilize the API to retrieve it.
